# %% [markdown]
# # Mnist auswerten mit neuronalem Netzwerk
# ## Mit einer Dense Layer

# %%
#pip install tensorflow

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, Flatten,Input
from keras.models import Sequential
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

print("Tensorflow version " + tf.__version__)

EPOCHS = 10
# Out:
# Tensorflow version 2.9.1

# %%
# load dataset
(trainX, trainY), (testX, testY) = mnist.load_data()

#trainX = trainX.reshape(trainX.shape[0],28*28) #V2
#testX = testX.reshape(testY.shape[0],28*28)    #V2

# one hot encode target values
trainY = to_categorical(trainY)
testY = to_categorical(testY)

# %%
# Create simple Neural Network model
#model = Sequential()
#model.add(Flatten(input_shape=(28,28)))
#model.add(Dense(10, activation='softmax'))

model = Sequential(
    [
       ##Input(shape=(28*28,)),       #V2
       Flatten(input_shape=(28,28)), #V1
       Dense(10, activation='softmax')
    ])


# print model layers
model.summary()

model.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the Neural Network model
history = model.fit(trainX, trainY, epochs=EPOCHS, validation_data=(testX,testY))

# Making predictions using our trained model
predictions = model.predict(testX)
#print(np.shape(predictions))
predictions = np.argmax(predictions, axis=1)
#print(np.shape(predictions))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 200)               157000
#
#  dense_7 (Dense)             (None, 100)               20100
#
#  dense_8 (Dense)             (None, 60)                6060
#
#  dense_9 (Dense)             (None, 30)                1830
#
#  dense_10 (Dense)            (None, 10)                310
#
# =================================================================
# Total params: 185,300
# Trainable params: 185,300
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 2.1062 - accuracy: 0.4703 - val_loss: 1.8089 - val_accuracy: 0.6466
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.3880 - accuracy: 0.6892 - val_loss: 1.0225 - val_accuracy: 0.7872
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.8107 - accuracy: 0.8525 - val_loss: 0.6245 - val_accuracy: 0.8891
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5146 - accuracy: 0.9077 - val_loss: 0.4132 - val_accuracy: 0.9204
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3606 - accuracy: 0.9281 - val_loss: 0.3179 - val_accuracy: 0.9324
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2777 - accuracy: 0.9412 - val_loss: 0.2603 - val_accuracy: 0.9420
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2300 - accuracy: 0.9487 - val_loss: 0.2132 - val_accuracy: 0.9507
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1975 - accuracy: 0.9541 - val_loss: 0.1960 - val_accuracy: 0.9534
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1713 - accuracy: 0.9595 - val_loss: 0.1782 - val_accuracy: 0.9574
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1547 - accuracy: 0.9629 - val_loss: 0.1658 - val_accuracy: 0.9581
# 313/313 [==============================] - 1s 2ms/step

# %%
#print(history.history)
#print(history.epoch)
#print("loss:\n",history.history["loss"])
#print("val_loss:\n",history.history["val_loss"])
#print("accuracy:\n",history.history["accuracy"])
#print("val_accuracy:\n",history.history["val_accuracy"])

# %%
from tensorflow.keras import models
# Save the model
model.save("my_model")
# It can be used to reconstruct the model identically.
reconstructed_model = models.load_model("my_model")
# Evaluate the model
loss, acc = reconstructed_model.evaluate(testX, testY)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# INFO:tensorflow:Assets written to: my_model\assets
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1658 - accuracy: 0.9581
# Restored model, accuracy: 95.81%

# %%
epoches = np.array(history.epoch)+1
plt.title('Accuracy')
plt.plot(epoches,history.history["accuracy"],color='red',label="train accuracy")
plt.plot(epoches,history.history["val_accuracy"],color='green',label="validation accuracy")
plt.legend(loc='lower right')
plt.xlabel('Epoches')       # Beschriftung der X-Achse
plt.ylabel('accuracy')      # Beschriftung der y-Achse 
plt.grid(True)              # Grid aktivieren
plt.axis([0, 10, 0, 1])     # X-Range von 0 bis 10 Y-Range von 0 - 1
plt.show()                  # Plot ausgeben

# %%
# Display some predictions on test data
fig, axes = plt.subplots(ncols=10, sharex=False, sharey=True, figsize=(20, 4))
for i in range(10):
	axes[i].set_title(predictions[i])
	axes[i].imshow(testX[i], cmap='gray')
	axes[i].get_xaxis().set_visible(False)
	axes[i].get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Visualisierung der Gewichte

# %%
denseLayer = model.layers[1]
weights, bias = denseLayer.get_weights()

fig, axes = plt.subplots(ncols=10, sharex=False, sharey=True, figsize=(20, 20))
for i in range(10):
    wei = weights[:,i].reshape(28,28)
    f_min, f_max = wei.min(), wei.max()
     #print(str(f_min),str(f_max))
    wei = (wei - f_min) / (f_max - f_min) 
    wei=wei*255
    wei = wei.astype(int)
    axes[i].set_title(str(i))
    axes[i].imshow(wei, cmap='gray')
    axes[i].get_xaxis().set_visible(False)
    axes[i].get_yaxis().set_visible(False)
plt.show()
